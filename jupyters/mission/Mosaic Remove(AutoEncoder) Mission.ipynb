# %% [markdown]
# # [과제3] 얼굴 모자이크 제거 오토인코더 제작

# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense, Input, Conv2D, BatchNormalization, Activation, MaxPool2D, Dropout, Conv2DTranspose, concatenate
from keras.models import Sequential, Model
from skimage.transform import resize
from sklearn.model_selection import train_test_split

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from IPython.display import Image
from PIL import Image

warnings.filterwarnings('ignore')
# %matplotlib inline

SEED = 34

# %%
data = np.load('.npzs/pfcn.npz')

train_images = data['train_images']
test_images = data['test_images']
train_mattes = data['train_mattes']
test_mattes = data['test_mattes']

# %%
np.shape(train_images), np.shape(test_images), np.shape(
    train_mattes), np.shape(test_mattes)
# Out:
# ((1700, 100, 75, 3), (300, 100, 75, 3), (1700, 100, 75), (300, 100, 75))

# %%
y = np.concatenate([train_images, test_images])

# %%
np.shape(y)
# Out:
# (2000, 100, 75, 3)

# %%
import os

base = '.mosaic'

if not os.path.exists(base):
    os.mkdir(base)

before = base + '/before'
after = base + '/after'

if not os.path.exists(before):
    os.mkdir(before)

if not os.path.exists(after):
    os.mkdir(after)

# %%
cnt = 1
for a in y:
    new_arr = ((a - a.min()) * (1 / (a.max() - a.min()) * 255)).astype('uint8')
    im = Image.fromarray(new_arr)
    im.save(f'{before}/{cnt}.jpg')
    cnt += 1

# %%
xml = 'haarcascade_frontalface_default.xml'
face_cascade = cv2.CascadeClassifier(xml)

cnt = 1
for _ in range(2000):
    src = cv2.imread(f'{before}/{cnt}.jpg')
    src_gray = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(src_gray)

    ratio = 0.1

    for x, y, w, h in faces:
        small = cv2.resize(src[y:y + h, x:x + w],
                           None,
                           fx=ratio,
                           fy=ratio,
                           interpolation=cv2.INTER_NEAREST)
        src[y:y + h, x:x + w] = cv2.resize(small, (w, h),
                                           interpolation=cv2.INTER_NEAREST)

    cv2.imwrite(f'{after}/{cnt}.jpg', src)
    cnt += 1

# %%
result = []
cnt = 1
for _ in range(2000):
    img = Image.open(f'{after}/{cnt}.jpg')
    img = np.array(img)
    img = img / 255.
    result.append(img)
    cnt += 1

X = np.array(result)

# %%
np.shape(X), np.shape(y)
# Out:
# ((2000, 100, 75, 3), (2000, 100, 75, 3))

# %%
plt.figure(figsize=(18, 10))

plt.subplot(1, 2, 1)
plt.imshow(X[1])

plt.subplot(1, 2, 2)
plt.imshow(y[1])

# %%
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.2,
                                                    random_state=SEED)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((1600, 100, 75, 3), (400, 100, 75, 3), (1600, 100, 75, 3), (400, 100, 75, 3))

# %%
def conv2d_block(x, channel):
    x = Conv2D(channel, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(channel, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

# %%
def unet_like():
    inputs = Input((100, 75, 3))

    c0 = conv2d_block(inputs, 8)
    p0 = MaxPool2D(2)(c0)
    p0 = Dropout(0.1)(p0)

    c1 = conv2d_block(p0, 16)
    p1 = MaxPool2D(2)(c1)
    p1 = Dropout(0.1)(p1)

    c2 = conv2d_block(p1, 32)
    p2 = MaxPool2D(2)(c2)
    p2 = Dropout(0.1)(p2)

    c3 = conv2d_block(p2, 64)
    p3 = MaxPool2D(2)(c3)
    p3 = Dropout(0.1)(p3)

    c4 = conv2d_block(p3, 128)
    p4 = MaxPool2D(2)(c4)
    p4 = Dropout(0.1)(p4)

    c5 = conv2d_block(p4, 256)

    u6 = Conv2DTranspose(128, 2, 2)(c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(0.1)(u6)
    c6 = conv2d_block(u6, 128)

    u7 = Conv2DTranspose(64, 2, 2, padding="valid", output_padding=(0, 1))(c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(0.1)(u7)
    c7 = conv2d_block(u7, 64)

    u8 = Conv2DTranspose(32, 2, 2, padding="valid", output_padding=(1, 0))(c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(0.1)(u8)
    c8 = conv2d_block(u8, 32)

    u9 = Conv2DTranspose(16, 2, 2, padding="valid", output_padding=(0, 1))(c8)
    u9 = concatenate([u9, c1])
    u9 = Dropout(0.1)(u9)
    c9 = conv2d_block(u9, 16)

    u10 = Conv2DTranspose(16, 2, 2, padding="valid", output_padding=(0, 1))(c9)
    outputs = Conv2D(3, 1, activation="sigmoid")(u10)

    model = Model(inputs, outputs)

    return model

# %%
model_unet = unet_like()
model_unet.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 100, 75, 3)] 0
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 100, 75, 8)   224         input_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 100, 75, 8)   32          conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 100, 75, 8)   0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 100, 75, 8)   584         activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 100, 75, 8)   32          conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 100, 75, 8)   0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 50, 37, 8)    0           activation_53[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 50, 37, 8)    0           max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 50, 37, 16)   1168        dropout_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 50, 37, 16)   64          conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 50, 37, 16)   0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 50, 37, 16)   2320        activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 50, 37, 16)   64          conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 50, 37, 16)   0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 25, 18, 16)   0           activation_55[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 25, 18, 16)   0           max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 25, 18, 32)   4640        dropout_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 25, 18, 32)   128         conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 25, 18, 32)   0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 25, 18, 32)   9248        activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 25, 18, 32)   128         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 25, 18, 32)   0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 12, 9, 32)    0           activation_57[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (None, 12, 9, 32)    0           max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 12, 9, 64)    18496       dropout_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 12, 9, 64)    256         conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 12, 9, 64)    0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 12, 9, 64)    36928       activation_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 12, 9, 64)    256         conv2d_61[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 12, 9, 64)    0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 6, 4, 64)     0           activation_59[0][0]
# __________________________________________________________________________________________________
# dropout_26 (Dropout)            (None, 6, 4, 64)     0           max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 6, 4, 128)    73856       dropout_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 6, 4, 128)    512         conv2d_62[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 6, 4, 128)    0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 6, 4, 128)    147584      activation_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 6, 4, 128)    512         conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 6, 4, 128)    0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 3, 2, 128)    0           activation_61[0][0]
# __________________________________________________________________________________________________
# dropout_27 (Dropout)            (None, 3, 2, 128)    0           max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 3, 2, 256)    295168      dropout_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 3, 2, 256)    1024        conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 3, 2, 256)    0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 3, 2, 256)    590080      activation_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 3, 2, 256)    1024        conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 3, 2, 256)    0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_12 (Conv2DTran (None, 6, 4, 128)    131200      activation_63[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 6, 4, 256)    0           conv2d_transpose_12[0][0]
#                                                                  activation_61[0][0]
# __________________________________________________________________________________________________
# dropout_28 (Dropout)            (None, 6, 4, 256)    0           concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 6, 4, 128)    295040      dropout_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 6, 4, 128)    512         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 6, 4, 128)    0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 6, 4, 128)    147584      activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 6, 4, 128)    512         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 6, 4, 128)    0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_13 (Conv2DTran (None, 12, 9, 64)    32832       activation_65[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 12, 9, 128)   0           conv2d_transpose_13[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# dropout_29 (Dropout)            (None, 12, 9, 128)   0           concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 12, 9, 64)    73792       dropout_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 12, 9, 64)    256         conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 12, 9, 64)    0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 12, 9, 64)    36928       activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 12, 9, 64)    256         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 12, 9, 64)    0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_14 (Conv2DTran (None, 25, 18, 32)   8224        activation_67[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 25, 18, 64)   0           conv2d_transpose_14[0][0]
#                                                                  activation_57[0][0]
# __________________________________________________________________________________________________
# dropout_30 (Dropout)            (None, 25, 18, 64)   0           concatenate_12[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 25, 18, 32)   18464       dropout_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 25, 18, 32)   128         conv2d_70[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 25, 18, 32)   0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 25, 18, 32)   9248        activation_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 25, 18, 32)   128         conv2d_71[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 25, 18, 32)   0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_15 (Conv2DTran (None, 50, 37, 16)   2064        activation_69[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 50, 37, 32)   0           conv2d_transpose_15[0][0]
#                                                                  activation_55[0][0]
# __________________________________________________________________________________________________
# dropout_31 (Dropout)            (None, 50, 37, 32)   0           concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 50, 37, 16)   4624        dropout_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 50, 37, 16)   64          conv2d_72[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 50, 37, 16)   0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 50, 37, 16)   2320        activation_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 50, 37, 16)   64          conv2d_73[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 50, 37, 16)   0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_16 (Conv2DTran (None, 100, 75, 16)  1040        activation_71[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 100, 75, 3)   51          conv2d_transpose_16[0][0]
# ==================================================================================================
# Total params: 1,949,659
# Trainable params: 1,946,683
# Non-trainable params: 2,976
# __________________________________________________________________________________________________

# %%
model_unet.compile(loss="mae", optimizer="adam", metrics=["accuracy"])

# %%
hist = model_unet.fit(X_train,
                      y_train,
                      validation_data=(X_test, y_test),
                      epochs=30)
# Out:
# Epoch 1/30
# 50/50 [==============================] - 5s 39ms/step - loss: 0.1659 - accuracy: 0.4733 - val_loss: 0.2301 - val_accuracy: 0.4975
# Epoch 2/30
# 50/50 [==============================] - 1s 25ms/step - loss: 0.1128 - accuracy: 0.6228 - val_loss: 0.2056 - val_accuracy: 0.6946
# Epoch 3/30
# 50/50 [==============================] - 1s 25ms/step - loss: 0.1010 - accuracy: 0.7018 - val_loss: 0.1742 - val_accuracy: 0.6881
# Epoch 4/30
# 50/50 [==============================] - 1s 24ms/step - loss: 0.0941 - accuracy: 0.7377 - val_loss: 0.1501 - val_accuracy: 0.6872
# Epoch 5/30
# 50/50 [==============================] - 1s 24ms/step - loss: 0.0913 - accuracy: 0.7587 - val_loss: 0.1334 - val_accuracy: 0.7417
# Epoch 6/30
# 50/50 [==============================] - 1s 26ms/step - loss: 0.0885 - accuracy: 0.7678 - val_loss: 0.1038 - val_accuracy: 0.7349
# Epoch 7/30
# 50/50 [==============================] - 1s 27ms/step - loss: 0.0866 - accuracy: 0.7658 - val_loss: 0.0918 - val_accuracy: 0.7449
# Epoch 8/30
# 50/50 [==============================] - 1s 26ms/step - loss: 0.0851 - accuracy: 0.7714 - val_loss: 0.0899 - val_accuracy: 0.7570
# Epoch 9/30
# 50/50 [==============================] - 1s 25ms/step - loss: 0.0836 - accuracy: 0.7713 - val_loss: 0.0838 - val_accuracy: 0.7667
# Epoch 10/30
# 50/50 [==============================] - 1s 28ms/step - loss: 0.0827 - accuracy: 0.7758 - val_loss: 0.0811 - val_accuracy: 0.7458
# Epoch 11/30
# 50/50 [==============================] - 1s 25ms/step - loss: 0.0817 - accuracy: 0.7693 - val_loss: 0.0799 - val_accuracy: 0.7890
# Epoch 12/30
# 50/50 [==============================] - 1s 25ms/step - loss: 0.0816 - accuracy: 0.7782 - val_loss: 0.0801 - val_accuracy: 0.7827
# Epoch 13/30
# 50/50 [==============================] - 1s 25ms/step - loss: 0.0798 - accuracy: 0.7783 - val_loss: 0.0791 - val_accuracy: 0.7868
# Epoch 14/30
# 50/50 [==============================] - 1s 27ms/step - loss: 0.0798 - accuracy: 0.7771 - val_loss: 0.0814 - val_accuracy: 0.7471
# Epoch 15/30
# 50/50 [==============================] - 1s 26ms/step - loss: 0.0787 - accuracy: 0.7775 - val_loss: 0.0843 - val_accuracy: 0.7155
# Epoch 16/30
# 50/50 [==============================] - 1s 24ms/step - loss: 0.0792 - accuracy: 0.7781 - val_loss: 0.0832 - val_accuracy: 0.7749
# Epoch 17/30
# 50/50 [==============================] - 1s 27ms/step - loss: 0.0778 - accuracy: 0.7788 - val_loss: 0.0760 - val_accuracy: 0.7601
# Epoch 18/30
# 50/50 [==============================] - 1s 27ms/step - loss: 0.0779 - accuracy: 0.7801 - val_loss: 0.0780 - val_accuracy: 0.7346
# Epoch 19/30
# 50/50 [==============================] - 1s 25ms/step - loss: 0.0765 - accuracy: 0.7815 - val_loss: 0.0769 - val_accuracy: 0.7817
# Epoch 20/30
# 50/50 [==============================] - 1s 25ms/step - loss: 0.0763 - accuracy: 0.7851 - val_loss: 0.0782 - val_accuracy: 0.7749
# Epoch 21/30
# 50/50 [==============================] - 1s 25ms/step - loss: 0.0763 - accuracy: 0.7833 - val_loss: 0.0780 - val_accuracy: 0.7816
# Epoch 22/30
# 50/50 [==============================] - 1s 25ms/step - loss: 0.0758 - accuracy: 0.7814 - val_loss: 0.0752 - val_accuracy: 0.7768
# Epoch 23/30
# 50/50 [==============================] - 1s 25ms/step - loss: 0.0750 - accuracy: 0.7794 - val_loss: 0.0759 - val_accuracy: 0.7480
# Epoch 24/30
# 50/50 [==============================] - 1s 25ms/step - loss: 0.0746 - accuracy: 0.7797 - val_loss: 0.0745 - val_accuracy: 0.7485
# Epoch 25/30
# 50/50 [==============================] - 1s 30ms/step - loss: 0.0741 - accuracy: 0.7851 - val_loss: 0.0738 - val_accuracy: 0.7630
# Epoch 26/30
# 50/50 [==============================] - 1s 27ms/step - loss: 0.0745 - accuracy: 0.7855 - val_loss: 0.0753 - val_accuracy: 0.7961
# Epoch 27/30
# 50/50 [==============================] - 1s 25ms/step - loss: 0.0736 - accuracy: 0.7834 - val_loss: 0.0780 - val_accuracy: 0.7943
# Epoch 28/30
# 50/50 [==============================] - 1s 24ms/step - loss: 0.0731 - accuracy: 0.7846 - val_loss: 0.0748 - val_accuracy: 0.7900
# Epoch 29/30
# 50/50 [==============================] - 1s 26ms/step - loss: 0.0730 - accuracy: 0.7871 - val_loss: 0.0748 - val_accuracy: 0.8013
# Epoch 30/30
# 50/50 [==============================] - 1s 25ms/step - loss: 0.0723 - accuracy: 0.7871 - val_loss: 0.0755 - val_accuracy: 0.7937

# %%
plt.figure(figsize=(12, 8))
plt.plot(hist.history['loss'], label='loss')
plt.plot(hist.history['accuracy'], label='accuracy')
plt.plot(hist.history['val_loss'], label='val_loss')
plt.plot(hist.history['val_accuracy'], label='val_accuracy')
plt.legend()
plt.show()

# %%
result = model_unet.predict(X_test[3:4])

plt.subplot(1, 2, 1)
plt.title('source')
plt.imshow(X_test[3])

plt.subplot(1, 2, 2)
plt.title('unet_model_result')
plt.imshow(result[0])

# %% [markdown]
# ### AI가 흐릿한 얼굴을 64배 더 선명하게 만들어준다.
#
# http://blockchainai.kr/client/news/newsView.asp?nIdx=35343
